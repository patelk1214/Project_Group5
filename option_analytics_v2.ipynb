# %%
""" 
Import necessary libraries for performing mathematical and visulaization 
"""

import pandas as pd
import datetime as dt
import numpy as np
import json
import requests
import urllib.request
import datetime
from pathlib import Path
from dotenv import load_dotenv
import os
from blackscholesmodel import euro_vanilla, implied_vol, delta, vega, get_d1_d2

pd.set_option("mode.chained_assignment", None)

option_path = Path("/option_data")

load_dotenv('example.env')
iex_token = os.getenv("IEX_token")
# print(type(iex_token))


def find_atm_strike(strikes, cur_price): 
    """ This function returns closest strike price from the current stock price. 
    It take list of strike prices and current price as input.
    """
    
    min_diff = None
    atm_strike = None
    
    for strike in strikes:
        if min_diff == None: 
            min_diff = abs(strike - cur_price) 
        elif abs(strike - cur_price)  < min_diff: 
            min_diff = abs(strike - cur_price)
            atm_strike = strike
            
    return atm_strike

# %%
"""
Retrieve End of the Day Option Prices from IEX Cloud for tickes in scope, one at a time. 
Load the Options data into pandas dataframe. 

"""

tickers = ['AAPL', 'MSFT', 'GOOG', 'TSLA', 'TWTR', 'JPM', 'DAL', 'PFE', 'MRNA','XOM', 'CVX','AMZN','ZM','FB', 'GILD', 'SPY'] 

locally_loaded = [] 

for ticker in tickers: 
    fname = '.'.join([ticker, 'csv'])
    file_path = Path(". option_path/" + fname)

    df_flag = False
    
    try: 
        option_df = pd.read_csv('option_data/' + fname, )
        locally_loaded.append(ticker)
        df_flag = True
    except Exception as e: 
        print(e)
    
    if not df_flag:
        try:
            # Retrive available option matuirties for the ticker from IEX 
            
            url = 'https://cloud.iexapis.com/stable/stock/' + ticker + '/options/?token=' + iex_token
            option_maturities  = requests.get(url).json()
            maturities = ['20210319', '20210416']
        except Exception as e:
            print(e)

        try: 
            option_dfs = []
            for date in maturities: 
                
                # retrieve the Option Chain for each maturity from IEX 
                
                url = 'https://cloud.iexapis.com/stable/stock/' + ticker + '/options/' + date + '?token=' + iex_token
                option_data = requests.get(url).json()
                option_df = pd.DataFrame(option_data)
                option_df = option_df.loc[option_df['exerciseStyle'] == 'A']
                option_dfs.append(option_df)
        except Exception as e:
            print(e)
        
        # Combine options data for all maturities into single dataframe & export to local warehouse folder
        final_option_df = pd.concat(option_dfs, axis=0)
        final_option_df.to_csv("option_data/" + fname)
        
# option_df.head(5)
print(f'Loaded from local folder: {locally_loaded}')
# Out:
# Loaded from local folder: ['AAPL', 'MSFT', 'GOOG', 'TSLA', 'TWTR', 'JPM', 'DAL', 'PFE', 'MRNA', 'XOM', 'CVX', 'AMZN', 'ZM', 'FB', 'GILD', 'SPY']

# %%
# Retrieve close price, Market Cap, 52 Week High/Low and other details from IEX Quotes

symbols = ','.join(tickers)
quote_url = 'https://cloud.iexapis.com/stable/stock/market/batch?symbols=' + symbols + '&types=quote&token=' + iex_token
cols = ['close', 'marketCap', 'week52High', 'week52Low']

hist_data = {}

try: 
    quotes = requests.get(quote_url).json()
    for k, v in quotes.items(): 
        
        for col in cols: 
            if k not in hist_data: 
                hist_data[k] = {}
            
            if col == 'close':
                if v['quote'][col] == None:
                    hist_data[k][col] = v['quote']['previousClose']
                else: 
                    hist_data[k][col] = v['quote'][col]
            else: 
                hist_data[k][col] = v['quote'][col]
                
except Exception as e:
    print(e)

# %%
print(hist_data)
# Out:
# {'AAPL': {'close': 129.71, 'marketCap': 2177583932160, 'week52High': 144.87, 'week52Low': 52.74}, 'MSFT': {'close': 243.79, 'marketCap': 1818277377108, 'week52High': 245.56, 'week52Low': 131.19}, 'GOOG': {'close': 2117.2, 'marketCap': 1423800621670, 'week52High': 2152.68, 'week52Low': 1013.54}, 'TSLA': {'close': 787.38, 'marketCap': 750293487739, 'week52High': 900.4, 'week52Low': 70.1}, 'TWTR': {'close': 72.26, 'marketCap': 57658535733, 'week52High': 74.96, 'week52Low': 20}, 'JPM': {'close': 145.59, 'marketCap': 452322852519, 'week52High': 148.55, 'week52Low': 74.16}, 'DAL': {'close': 44.38, 'marketCap': 29297313390, 'week52High': 58.02, 'week52Low': 17.51}, 'PFE': {'close': 34.56, 'marketCap': 191570138785, 'week52High': 42.62, 'week52Low': 26.77}, 'MRNA': {'close': 169.57, 'marketCap': 69059327525, 'week52High': 189.26, 'week52Low': 17.91}, 'XOM': {'close': 52.02, 'marketCap': 221496044062, 'week52High': 54.97, 'week52Low': 27.81}, 'CVX': {'close': 95, 'marketCap': 179094991898, 'week52High': 104.54, 'week52Low': 49.4}, 'AMZN': {'close': 3328.23, 'marketCap': 1650196769753, 'week52High': 3552.25, 'week52Low': 1626.03}, 'ZM': {'close': 417.91, 'marketCap': 119383615244, 'week52High': 588.84, 'week52Low': 97.02}, 'FB': {'close': 269.39, 'marketCap': 746135523464, 'week52High': 304.67, 'week52Low': 137.1}, 'GILD': {'close': 65.23, 'marketCap': 81009256629, 'week52High': 83.38, 'week52Low': 56.4}, 'SPY': {'close': 390.82, 'marketCap': 337369465100, 'week52High': 394.17, 'week52Low': 215.52}}

# %%
## IEX: Get historical closing prices, market cap, peRatio, 52 wk hi/low for16 tickers and place into df
locally_loaded = []
for ticker in tickers:
    fname = '.'.join([ticker, 'csv'])
    
    file_path = Path('/option_data/hist_price/' + fname)
    df_flag = False
    
    try:
        stock_df = pd.read_csv("option_data/hist_price/" + fname)
        locally_loaded.append(ticker)
        df_flag = True
    except Exception as e:
        print(e)
                     
    if not df_flag:
        print(ticker)
        try:
            url = 'https://cloud.iexapis.com/stable/stock/' + ticker + '/chart/1y?token=' + iex_token
            stock_chart = requests.get(url).json()
            stock_df = pd.DataFrame(stock_chart)
            stock_df.to_csv("option_data/hist_price/" + fname)
        except Exception as e:
            print(e)
                     
    # Calculate daily returns
    daily_returns = stock_df['close'].pct_change()
    # compute StDev
    rolling_std30 = daily_returns.rolling(window=30).std()
    # daily_std = daily_returns.std()
    annualized_std = (rolling_std30 * np.sqrt(252)).mean()
    
    # assign Hist Vol to existing hist_data dictionary, not new dictionary
    hist_data[ticker]['histVol'] = annualized_std

# print(hist_data)
print(f'Loaded from local folder: {locally_loaded}')
# Out:
# Loaded from local folder: ['AAPL', 'MSFT', 'GOOG', 'TSLA', 'TWTR', 'JPM', 'DAL', 'PFE', 'MRNA', 'XOM', 'CVX', 'AMZN', 'ZM', 'FB', 'GILD', 'SPY']

# %%
## Retrive Treasury Rates from IEX Cloud and add to hist_data  dictionary
tenors = ['DGS3MO', 'DGS1MO']
tenor_data = {}
for tenor in tenors:
    url = 'https://cloud.iexapis.com/stable/time-series/treasury/' + tenor + '?token=' + iex_token
#     print(url)
    treasury_maturities  = requests.get(url).json()
#     print(type(treasury_maturities))
    for t in treasury_maturities:
        tenor_data[t['key']] = t['value']
hist_data['tenor_rate'] = tenor_data
tenor_data
# Out:
# {'DGS3MO': 0.04, 'DGS1MO': 0.03}

# %%
''' 
    Load Call & Put option data for different maurities into seperate Dataframe and store in Dictionary for later use.

'''
option_data= {}
tickers = ['AAPL', 'MSFT', 'GOOG', 'TSLA', 'TWTR', 'JPM', 'DAL', 'PFE', 'MRNA','XOM', 'CVX','AMZN','ZM','FB', 'GILD', 'SPY']
for ticker in tickers: 
    print(f'Processing {ticker} ...')
    option_data[ticker] = {}
    
    fname = '.'.join([ticker, 'csv'])
    cur_close = hist_data[ticker]['close']
#     print(cur_close)
    
    try: 
        option_df = pd.read_csv('option_data/' + fname)
                
    except Exception as e:
        print(e)
        continue
           
    call_option_df = option_df.loc[option_df['side'] == 'call'].sort_values(by='strikePrice', ascending=True)
    put_option_df = option_df.loc[option_df['side'] == 'put'].sort_values(by='strikePrice', ascending=True)
    cols = ['symbol', 'expirationDate', 'side','strikePrice', 'close', 'ask', 'bid', 'volume', 'openInterest']

    call_option_df = call_option_df[cols]
    put_option_df = put_option_df[cols]
    maturities = [20210319, 20210416]
    
    for expiry in maturities:
        option_data[ticker][expiry] = {}
        call_option_exp_df = call_option_df.loc[call_option_df['expirationDate'] == expiry]
        put_option_exp_df = put_option_df.loc[put_option_df['expirationDate'] == expiry]
        
        if put_option_exp_df.empty:
            continue
        
        put_strikes = put_option_exp_df['strikePrice'].tolist()
        put_atm_strike = find_atm_strike(put_strikes, cur_close)

        call_strikes = call_option_exp_df['strikePrice'].tolist()
        call_atm_strike = find_atm_strike(call_strikes, cur_close)

        put_option_exp_df = put_option_exp_df.reset_index()
        put_option_exp_df.drop('index', axis=1,  inplace=True)
        call_option_exp_df = call_option_exp_df.reset_index()
        call_option_exp_df.drop('index', axis=1,  inplace=True)

        put_atm_strike_index = put_option_exp_df.loc[put_option_exp_df['strikePrice']==put_atm_strike].index[0]
        call_atm_strike_index = call_option_exp_df.loc[call_option_exp_df['strikePrice']==call_atm_strike].index[0]

        put_lower_index = put_atm_strike_index - min(10, put_atm_strike_index)
        put_upper_index = put_atm_strike_index + min(11, put_option_exp_df.shape[0] - put_atm_strike_index)

        call_lower_index = call_atm_strike_index - min(10, call_atm_strike_index)
        call_upper_index = call_atm_strike_index + min(11, call_option_exp_df.shape[0] - call_atm_strike_index)

        final_put_df = put_option_exp_df.iloc[put_lower_index:put_upper_index, ]
        final_put_df = final_put_df.reset_index()
        final_put_df.drop('index', axis=1,  inplace=True)
        final_put_df['mid_price'] = (final_put_df['ask'] +  final_put_df['bid'])/2
        option_data[ticker][expiry]['put'] = final_put_df

        final_call_df = call_option_exp_df.iloc[call_lower_index:call_upper_index, ]
        final_call_df = final_call_df.reset_index()
        final_call_df.drop('index', axis=1,  inplace=True)
        final_call_df['mid_price'] = (final_call_df['ask'] +  final_call_df['bid'])/2
        option_data[ticker][expiry]['call'] = final_call_df

# print(option_data['AAPL'][20210319]['call'].head(5))
# option_data['AAPL'][20210416]['call'].tail(10)
# Out:
# Processing AAPL ...
# Processing MSFT ...
# Processing GOOG ...
# Processing TSLA ...
# Processing TWTR ...
# Processing JPM ...
# Processing DAL ...
# Processing PFE ...
# Processing MRNA ...
# Processing XOM ...
# Processing CVX ...
# Processing AMZN ...
# Processing ZM ...
# Processing FB ...
# Processing GILD ...
# Processing SPY ...

# %%
# Calculate Implied Volatity & Options Greeks for option chain one ticker at a time and update relevant ticker dataframe in the Option Data dictionary. 

option_data_greeks= {}

r = 0.001
t = 30/365
hist_vol = 0.20

maturities = [20210319, 20210416]
# symbols = ['SPY']
for ticker in tickers: 
    s = hist_data[ticker]['close']
    print(f'{ticker}, stock price: {s}')
    
    for expiry in maturities:
        
        if not option_data[ticker][expiry]: 
            continue
        
        for side in ['call', 'put']:
#             print(option_data[ticker][expiry][side].head())
            option_data[ticker][expiry][side]['implied_vol'] = 1111111
            option_data[ticker][expiry][side]['delta'] = 1111111
            option_data[ticker][expiry][side]['vega'] = 1111111
            
            df2 = option_data[ticker][expiry][side].set_index('strikePrice')
            df3 = pd.Series(option_data[ticker][expiry][side].set_index('strikePrice')['mid_price'])
            callput = side
            strikes = list(df3.index)
            
            for strike in strikes:
                
                # Compute Implied volatility for each option strike using Black Scholes Model & Newton's method for root solving 
                
                mid_price = df3[strike]
                imp_vol = implied_vol(callput, s, strike, r, mid_price, t, hist_vol) 
                if imp_vol == 9999999:
                    print(f'Expiry: {expiry}, strike: {strike} : {side} option_price: {mid_price:.3f} vol: {imp_vol}')
                
                if imp_vol != 9999999:
                    # if the implied volatility is computed successfullt then calcutae Delta & Gama and add in to Option Dataframe
            
                    d1_option = get_d1_d2(s, strike, t, r, imp_vol)[0]
                    delta_option = delta(side, d1_option)
                    vega_option = vega(s, d1_option, t)
                    option_data[ticker][expiry][side]['implied_vol'].loc[option_data[ticker][expiry][side]['strikePrice'] == strike] = round(imp_vol * 100, 3)
                    option_data[ticker][expiry][side]['delta'].loc[option_data[ticker][expiry][side]['strikePrice'] == strike] = delta_option
                    option_data[ticker][expiry][side]['vega'].loc[option_data[ticker][expiry][side]['strikePrice'] == strike] = vega_option
            
            option_data[ticker][expiry][side] = option_data[ticker][expiry][side].loc[option_data[ticker][expiry][side]['implied_vol'] !=1111111]
                    
# option_data['AAPL'][20210319]['put'].tail(20)
# option_data['AAPL'][20210319]['call'].tail(20)
# Out:
# AAPL, stock price: 133.19
# Does not Converge
# Expiry: 20210319, strike: 107.5 : call option_price: 25.725 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 110.0 : call option_price: 23.500 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 115.0 : call option_price: 18.050 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 165.0 : call option_price: 0.225 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 170.0 : call option_price: 0.190 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 107.5 : put option_price: 0.355 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 110.0 : put option_price: 0.410 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 165.0 : put option_price: 32.100 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 175.0 : put option_price: 42.050 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 165.0 : put option_price: 32.575 vol: 9999999
# MSFT, stock price: 243.14
# Does not Converge
# Expiry: 20210319, strike: 195 : call option_price: 48.675 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 200 : call option_price: 43.800 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 290 : call option_price: 0.145 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 295 : call option_price: 0.135 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 195 : put option_price: 0.420 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 200 : put option_price: 0.515 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 350 : put option_price: 107.050 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 195 : call option_price: 49.350 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 200 : call option_price: 44.475 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 295 : call option_price: 0.490 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 195 : put option_price: 0.965 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 200 : put option_price: 1.100 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 300 : put option_price: 56.925 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 310 : put option_price: 67.200 vol: 9999999
# GOOG, stock price: 2121.9
# Does not Converge
# Expiry: 20210319, strike: 2600 : call option_price: 1.800 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 1600 : call option_price: 529.000 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 1680 : call option_price: 450.700 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 2700 : call option_price: 4.200 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 2800 : call option_price: 3.050 vol: 9999999
# TSLA, stock price: 796.22
# TWTR, stock price: 73.96
# Does not Converge
# Expiry: 20210319, strike: 44 : call option_price: 29.875 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 45 : call option_price: 29.175 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 46 : call option_price: 28.150 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 47 : call option_price: 26.975 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 48 : call option_price: 25.925 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 49 : call option_price: 25.175 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 50 : call option_price: 24.075 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 55 : call option_price: 19.425 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 60 : call option_price: 14.750 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 44 : put option_price: 0.125 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 45 : put option_price: 0.140 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 46 : put option_price: 0.160 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 47 : put option_price: 0.165 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 48 : put option_price: 0.170 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 49 : put option_price: 0.215 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 50 : put option_price: 0.200 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 55 : put option_price: 0.365 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 60 : put option_price: 0.715 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 43 : call option_price: 31.300 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 45 : call option_price: 29.350 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 48 : call option_price: 26.425 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 49 : call option_price: 25.450 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 50 : call option_price: 24.550 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 55 : call option_price: 19.825 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 60 : call option_price: 15.525 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 95 : call option_price: 1.490 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 100 : call option_price: 1.100 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 105 : call option_price: 0.910 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 40 : put option_price: 0.180 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 43 : put option_price: 0.205 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 45 : put option_price: 0.280 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 47 : put option_price: 0.335 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 49 : put option_price: 0.400 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 50 : put option_price: 0.470 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 55 : put option_price: 0.840 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 60 : put option_price: 1.500 vol: 9999999
# JPM, stock price: 144.65
# Does not Converge
# Expiry: 20210319, strike: 90 : call option_price: 54.950 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 95 : call option_price: 49.625 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 100 : call option_price: 44.950 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 110 : call option_price: 34.975 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 115 : call option_price: 29.600 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 175 : call option_price: 0.130 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 180 : call option_price: 0.075 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 190 : call option_price: 0.060 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 200 : call option_price: 0.035 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 95 : put option_price: 0.055 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 100 : put option_price: 0.070 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 105 : put option_price: 0.105 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 110 : put option_price: 0.145 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 115 : put option_price: 0.195 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 120 : put option_price: 0.315 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 180 : put option_price: 35.225 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 115 : call option_price: 30.850 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 175 : call option_price: 0.465 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 180 : call option_price: 0.315 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 185 : call option_price: 0.225 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 190 : call option_price: 0.155 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 200 : call option_price: 0.090 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 100 : put option_price: 0.245 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 105 : put option_price: 0.350 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 110 : put option_price: 0.510 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 115 : put option_price: 0.740 vol: 9999999
# DAL, stock price: 44.65
# Does not Converge
# Expiry: 20210319, strike: 26.0 : call option_price: 18.900 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 27.0 : call option_price: 17.900 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 30.0 : call option_price: 14.750 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 32.0 : call option_price: 12.675 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 33.0 : call option_price: 11.850 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 34.0 : call option_price: 10.825 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 35.0 : call option_price: 9.850 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 55.0 : call option_price: 0.325 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 60.0 : call option_price: 0.145 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 29.0 : put option_price: 0.090 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 30.0 : put option_price: 0.120 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 31.0 : put option_price: 0.170 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 32.0 : put option_price: 0.165 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 33.0 : put option_price: 0.190 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 34.0 : put option_price: 0.210 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 35.0 : put option_price: 0.280 vol: 9999999
# PFE, stock price: 34.69
# Does not Converge
# Expiry: 20210319, strike: 26 : call option_price: 8.825 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 28 : call option_price: 6.725 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 29 : call option_price: 5.575 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 42 : call option_price: 0.065 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 43 : call option_price: 0.055 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 44 : call option_price: 0.055 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 45 : call option_price: 0.075 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 22 : put option_price: 0.025 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 25 : put option_price: 0.015 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 26 : put option_price: 0.025 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 27 : put option_price: 0.050 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 36 : put option_price: 0.575 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 40 : put option_price: 3.400 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 45 : put option_price: 8.025 vol: 9999999
# MRNA, stock price: 178.53
# Does not Converge
# Expiry: 20210319, strike: 130 : call option_price: 50.400 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 135 : call option_price: 45.725 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 140 : call option_price: 41.475 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 145 : call option_price: 37.175 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 220 : call option_price: 3.850 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 225 : call option_price: 3.380 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 230 : call option_price: 2.650 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 235 : call option_price: 2.290 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 240 : call option_price: 1.850 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 130 : put option_price: 1.860 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 135 : put option_price: 2.310 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 140 : put option_price: 2.780 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 145 : put option_price: 3.675 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 220 : put option_price: 45.075 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 230 : put option_price: 53.450 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 240 : put option_price: 62.825 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 250 : put option_price: 72.800 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 130 : call option_price: 52.575 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 135 : call option_price: 48.000 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 140 : call option_price: 44.125 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 145 : call option_price: 40.275 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 220 : call option_price: 7.625 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 230 : call option_price: 6.075 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 240 : call option_price: 4.775 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 250 : call option_price: 3.650 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 260 : call option_price: 2.680 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 130 : put option_price: 3.725 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 135 : put option_price: 4.875 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 140 : put option_price: 5.175 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 145 : put option_price: 6.175 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 250 : put option_price: 74.375 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 270 : put option_price: 92.975 vol: 9999999
# XOM, stock price: 52.04
# Does not Converge
# Expiry: 20210319, strike: 22.5 : call option_price: 29.600 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 30.0 : call option_price: 22.175 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 40.0 : call option_price: 12.350 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 42.5 : call option_price: 9.800 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 70.0 : call option_price: 0.060 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 32.5 : put option_price: 0.055 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 35.0 : put option_price: 0.070 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 37.5 : put option_price: 0.100 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 40.0 : put option_price: 0.145 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 42.5 : put option_price: 0.235 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 35.0 : call option_price: 17.275 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 37.5 : call option_price: 14.950 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 40.0 : call option_price: 12.475 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 42.5 : call option_price: 10.250 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 65.0 : call option_price: 0.380 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 30.0 : put option_price: 0.095 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 32.5 : put option_price: 0.145 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 35.0 : put option_price: 0.205 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 37.5 : put option_price: 0.270 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 40.0 : put option_price: 0.375 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 42.5 : put option_price: 0.615 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 65.0 : put option_price: 13.250 vol: 9999999
# CVX, stock price: 93.13
# Does not Converge
# Expiry: 20210319, strike: 65.0 : call option_price: 28.275 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 67.5 : call option_price: 25.325 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 72.5 : call option_price: 19.900 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 75.0 : call option_price: 19.325 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 115.0 : call option_price: 0.115 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 125.0 : call option_price: 0.065 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 145.0 : call option_price: 0.090 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 165.0 : call option_price: 0.035 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 65.0 : put option_price: 0.075 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 70.0 : put option_price: 0.120 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 72.5 : put option_price: 0.140 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 75.0 : put option_price: 0.190 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 115.0 : call option_price: 0.385 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 120.0 : call option_price: 0.220 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 125.0 : call option_price: 0.090 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 65.0 : put option_price: 0.240 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 70.0 : put option_price: 0.310 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 75.0 : put option_price: 0.565 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 115.0 : put option_price: 22.175 vol: 9999999
# AMZN, stock price: 3268.95
# ZM, stock price: 444.51
# Does not Converge
# Expiry: 20210319, strike: 340 : call option_price: 109.700 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 350 : call option_price: 101.700 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 360 : call option_price: 93.050 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 340 : put option_price: 5.450 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 350 : put option_price: 7.000 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 360 : put option_price: 8.700 vol: 9999999
# FB, stock price: 273.97
# Does not Converge
# Expiry: 20210319, strike: 220 : call option_price: 54.900 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 225 : put option_price: 0.710 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 335 : put option_price: 61.850 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 345 : put option_price: 71.450 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 355 : put option_price: 81.650 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 195 : call option_price: 79.825 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 200 : call option_price: 75.000 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 220 : call option_price: 55.575 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 225 : put option_price: 1.925 vol: 9999999
# GILD, stock price: 64.8
# Does not Converge
# Expiry: 20210319, strike: 40.0 : call option_price: 24.975 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 50.0 : call option_price: 15.525 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 57.5 : call option_price: 7.225 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 80.0 : call option_price: 0.085 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 85.0 : call option_price: 0.105 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 95.0 : call option_price: 0.020 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 100.0 : call option_price: 0.015 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 35.0 : put option_price: 0.020 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 37.5 : put option_price: 0.030 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 40.0 : put option_price: 0.035 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 42.5 : put option_price: 0.040 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 45.0 : put option_price: 0.100 vol: 9999999
# Does not Converge
# Expiry: 20210319, strike: 50.0 : put option_price: 0.085 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 55.0 : call option_price: 9.525 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 57.5 : call option_price: 7.000 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 80.0 : call option_price: 0.175 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 85.0 : call option_price: 0.110 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 35.0 : put option_price: 0.040 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 50.0 : put option_price: 0.110 vol: 9999999
# Does not Converge
# Expiry: 20210416, strike: 80.0 : put option_price: 16.175 vol: 9999999
# SPY, stock price: 392.3

# %%
option_data['MSFT'][20210416]['put']
option_data['AMZN'][20210319]['put']
# Out:
#    symbol  expirationDate side  strikePrice   close     ask     bid  volume  \
# 0    AMZN        20210319  put         3185   72.80   73.60   71.35      19
# 1    AMZN        20210319  put         3190   74.52   75.45   73.20      19
# 2    AMZN        20210319  put         3195   77.55   77.35   75.10      22
# 3    AMZN        20210319  put         3200   79.00   79.35   77.05     133
# 4    AMZN        20210319  put         3210   83.55   83.30   81.35      19
# 5    AMZN        20210319  put         3220   86.85   87.45   85.15      26
# 6    AMZN        20210319  put         3230   91.00   91.80   89.40      16
# 7    AMZN        20210319  put         3240   94.93   96.25   93.75      21
# 8    AMZN        20210319  put         3250   98.70  100.90   98.50      76
# 9    AMZN        20210319  put         3260  104.10  105.70  103.05      24
# 10   AMZN        20210319  put         3270  109.00  110.65  107.95      26
# 11   AMZN        20210319  put         3280  113.32  115.75  113.00      27
# 12   AMZN        20210319  put         3290  118.50  121.00  118.20      12
# 13   AMZN        20210319  put         3300  126.90  125.95  123.85      40
# 14   AMZN        20210319  put         3350  153.32  155.30  153.00       8
# 15   AMZN        20210319  put         3400  187.25  188.65  185.85      21
# 16   AMZN        20210319  put         3405  201.10  192.15  189.35       2
# 17   AMZN        20210319  put         3410  192.40  196.35  192.85       1
# 18   AMZN        20210319  put         3415  193.60  199.95  196.40       2
# 19   AMZN        20210319  put         3450  217.00  225.40  222.45       2
# 20   AMZN        20210319  put         3470  216.20  240.95  237.95       1
#
#     openInterest  mid_price  implied_vol     delta        vega
# 0            245     72.475       29.671 -0.363415  397.405291
# 1            350     74.325       29.630 -0.370228  394.965452
# 2            315     76.225       29.593 -0.377104  392.662244
# 3           5827     78.200       29.567 -0.384056  390.489960
# 4            273     82.325       29.535 -0.398118  386.555297
# 5            405     86.300       29.424 -0.412153  383.208674
# 6            172     90.600       29.362 -0.426434  380.365831
# 7            266     95.000       29.289 -0.440816  378.048023
# 8            648     99.700       29.259 -0.455320  376.242327
# 9            162    104.375       29.182 -0.469875  374.949767
# 10           208    109.300       29.134 -0.484484  374.163276
# 11           117    114.375       29.087 -0.499117  373.881179
# 12           336    119.600       29.042 -0.513751  374.102513
# 13          4793    124.900       28.977 -0.528408  374.830978
# 14           417    154.150       28.817 -0.600310  386.152229
# 15          1311    187.250       28.774 -0.667945  410.846693
# 16            46    190.750       28.773 -0.674391  414.104783
# 17            21    194.600       28.868 -0.680124  417.159394
# 18            34    198.175       28.873 -0.686396  420.678656
# 19           117    223.925       28.875 -0.728669  450.000786
# 20            27    239.450       28.943 -0.750742  470.117571

# %%
# Concatenate put & call dfs of each ticker into final_option_data dictionary 

# create new dictionary option_data_conc
joint_option_data = {}
final_option_data = {}

symbols = ['JPM', 'SPY']
# tickers = ['AAPL', 'SPY', 'XOM', 'FB', 'TSLA', 'AMZN', 'CVX', 'GOOG', 'MRNA', 'MSFT', 'TWTR', 'JPM']

for ticker in tickers:
    joint_option_data[ticker] = {}
    
    option_df_list = []
    
    # set index to strikeprice for each put/call df
    
    for expiry in maturities:
        
        if not option_data[ticker][expiry]: 
            continue
            
        df1 = option_data[ticker][expiry]['call'].set_index('strikePrice')
        df1.drop(columns=['symbol', 'expirationDate', 'mid_price', 'close'], inplace=True)
        df1 = df1[['openInterest', 'volume', 'vega', 'implied_vol', 'delta', 'bid', 'ask', 'side']]
        df1.rename(columns={'openInterest': 'op_Int'}, inplace=True)
        df2 = option_data[ticker][expiry]['put'].set_index('strikePrice')
        df2.drop(columns=['symbol', 'expirationDate', 'mid_price', 'close'], inplace=True)
        df2 = df2[['side', 'ask', 'bid', 'delta', 'implied_vol', 'vega',  'volume', 'openInterest']]
        df2.rename(columns={'openInterest': 'op_Int'}, inplace=True)
        
        
        joint_option_data[ticker][expiry] = pd.concat([df1, df2], axis = 1, join = 'outer').reset_index()
        joint_option_data[ticker][expiry]['symbol'] = ticker
        joint_option_data[ticker][expiry]['exp_date'] = int(expiry)
        
        
    for expiry in maturities:
        
        if not option_data[ticker][expiry]: 
            continue
            
        option_df_list.append(joint_option_data[ticker][expiry])
        
    
    final_option_data[ticker]= pd.concat(option_df_list, axis = 0, join = 'inner')
    
    fname = ticker + '_option_chain.csv'
    
    final_option_data[ticker].to_csv("option_data/" + fname )

# print(joint_option_data['SPY'][20210319])
# print(final_option_data[ticker].tail(2))
# Out:
# C:\Users\KetanHina\study\cu-nyc-fin-pt-12-2020-u-c\03-Projects\Project-01

# %%
for ticker in final_option_data: 
    final_option_data[ticker]['Underlying_price'] = hist_data[ticker]['close']
    final_option_data[ticker]['hist_vol'] = round(hist_data[ticker]['histVol']*100, 3)

# hist_data['SPY']

# %%
# print(final_option_data.keys())

del final_option_dataframe

# final_option_dataframe = pd.DataFrame()
# print(final_option_dataframe.empty)
final_df_list = [] 

for k in final_option_data:
    final_df_list.append(final_option_data[k])
    
final_option_dataframe= pd.concat(final_df_list, axis = 0, join = 'inner')
final_option_dataframe = final_option_dataframe.reset_index()
final_option_dataframe.drop(columns=['index'], inplace=True)
    
    
# print(final_option_dataframe.shape)
# print(final_option_dataframe.columns)
# cols = ['symbol', 'exp_date','strikePrice', 'side', 'ask', 'bid', 'volume', 'openInterest', 'implied_vol', 'delta', 'vega', 'side', 'ask', 'bid', 'volume','openInterest',
#         'implied_vol', 'delta', 'vega']

final_option_dataframe.to_csv("option_data/Final_option_dataframe.csv" )
final_option_dataframe.head(20)
final_option_dataframe.tail(20)
# Out:
#      strikePrice   op_Int  volume       vega  implied_vol     delta    bid  \
# 426        383.0   3944.0   639.0  47.649730       27.291  0.635633  17.23
# 427        384.0   5904.0    31.0  47.167975       26.985  0.624057  16.50
# 428        385.0  67929.0    84.0  46.725824       26.690  0.612106  15.79
# 429        386.0   6602.0    11.0  46.329128       26.358  0.599909  15.14
# 430        387.0   6744.0    20.0  45.972996       26.059  0.587269  14.44
# 431        388.0   6470.0    48.0  45.662571       25.755  0.574287  13.76
# 432        389.0   1975.0    13.0  45.399371       25.458  0.560944  13.08
# 433        390.0  14874.0   104.0  45.185776       25.177  0.547241  12.43
# 434        391.0   3811.0    30.0  45.024722       24.890  0.533212  11.79
# 435        392.0   3808.0    74.0  44.918784       24.605  0.518855  11.17
# 436        393.0   1673.0   124.0  44.871082       24.334  0.504191  10.56
# 437        394.0   3094.0    73.0  44.884948       24.065  0.489235   9.97
# 438        395.0   5671.0    77.0  44.964153       23.796  0.473997   9.40
# 439        396.0   3838.0    31.0  45.112659       23.537  0.458522   8.84
# 440        397.0   4002.0    37.0  45.334686       23.288  0.442843   8.31
# 441        398.0   4788.0    30.0  45.635822       23.037  0.426950   7.79
# 442        399.0   1689.0    20.0  46.017922       22.818  0.411024   7.30
# 443        400.0  18836.0   195.0  46.491601       22.583  0.394895   6.82
# 444        401.0   4889.0    13.0  47.061131       22.356  0.378699   6.36
# 445        402.0   9089.0    56.0  47.729779       22.149  0.362563   5.93
#
#        ask  side side  ...    bid     delta  implied_vol       vega  volume  \
# 426  17.43  call  put  ...   9.05 -0.372938       29.853  47.287830   326.0
# 427  16.70  call  put  ...   9.33 -0.383669       29.534  46.875951    45.0
# 428  15.98  call  put  ...   9.62 -0.394721       29.229  46.497207   318.0
# 429  15.19  call  put  ...   9.91 -0.406036       28.912  46.154843    32.0
# 430  14.50  call  put  ...  10.22 -0.417666       28.605  45.848527   133.0
# 431  13.81  call  put  ...  10.55 -0.429599       28.308  45.580175    30.0
# 432  13.15  call  put  ...  10.88 -0.441813       28.009  45.351849    37.0
# 433  12.50  call  put  ...  11.24 -0.454322       27.729  45.164983   345.0
# 434  11.86  call  put  ...  11.60 -0.467095       27.433  45.021832    25.0
# 435  11.23  call  put  ...  11.97 -0.480138       27.154  44.924293   122.0
# 436  10.63  call  put  ...  12.37 -0.493412       26.903  44.874725   125.0
# 437  10.04  call  put  ...  12.79 -0.506931       26.634  44.875378    65.0
# 438   9.46  call  put  ...  13.22 -0.520653       26.380  44.928822    47.0
# 439   8.91  call  put  ...  13.68 -0.534516       26.151  45.037278    14.0
# 440   8.37  call  put  ...  14.15 -0.548538       25.925  45.203592    18.0
# 441   7.85  call  put  ...  14.64 -0.562661       25.712  45.430160    12.0
# 442   7.36  call  put  ...  15.07 -0.576897       25.501  45.720585     2.0
# 443   6.88  call  put  ...  15.58 -0.591173       25.302  46.077183    49.0
# 444   6.42  call  put  ...  16.12 -0.605451       25.116  46.502767     3.0
# 445   5.98  call  put  ...  16.70 -0.619424       24.989  46.990102     4.0
#
#       op_Int  symbol  exp_date  Underlying_price  hist_vol
# 426   2453.0     SPY  20210416             392.3    25.177
# 427   4085.0     SPY  20210416             392.3    25.177
# 428  19160.0     SPY  20210416             392.3    25.177
# 429   2315.0     SPY  20210416             392.3    25.177
# 430   3737.0     SPY  20210416             392.3    25.177
# 431   2071.0     SPY  20210416             392.3    25.177
# 432   2117.0     SPY  20210416             392.3    25.177
# 433  11867.0     SPY  20210416             392.3    25.177
# 434   1581.0     SPY  20210416             392.3    25.177
# 435    823.0     SPY  20210416             392.3    25.177
# 436   1277.0     SPY  20210416             392.3    25.177
# 437   1260.0     SPY  20210416             392.3    25.177
# 438   1735.0     SPY  20210416             392.3    25.177
# 439    890.0     SPY  20210416             392.3    25.177
# 440   1484.0     SPY  20210416             392.3    25.177
# 441    630.0     SPY  20210416             392.3    25.177
# 442    167.0     SPY  20210416             392.3    25.177
# 443   1023.0     SPY  20210416             392.3    25.177
# 444     68.0     SPY  20210416             392.3    25.177
# 445     44.0     SPY  20210416             392.3    25.177
#
# [20 rows x 21 columns]
